# %%
import pandas as pd
import numpy as np

from lactate_solver import lactate_solver

# %%
lactate_vector     = np.array([1.3, 1.5, 1.6, 1.5, 1.8, 1.9, 2.8, 4.8, 8.0, 15.2])
power_vector       = np.array([150, 175, 200, 220, 240, 260, 280, 300, 320, 340])
heartrate_vector   = np.array([109, 116, 126, 133, 138, 146, 153, 159, 164, 170])

# %%
ls = lactate_solver(lactate_vector=lactate_vector, heartrate_vector=heartrate_vector, power_vector=power_vector)

# %%
lt_solve = ls.find_LT_values(method_name='Dmax Mod') # 1+2
# Out:
# 251.216621870802

# %%
ls.plotter(**lt_solve)
